# %%
#Mountain Car
from stuff import *
from pylab import *
from random import *
import numpy
from rl import *

ACTION_SPACE=[-1,0,1] #Departing from the convention A = [0..card(A)] may be a bad idea. FIXME change this when I get around to it.

def mountain_car_next_state(state,action):
    position,speed=state
    next_speed = squeeze(speed+action*0.001+cos(3*position)*(-0.0025))
    next_position = squeeze(position+next_speed)
    if not -0.07 <= next_speed <= 0.07:
        next_speed = sign(next_speed)*0.07
    if not -1.2 <= next_position <= 0.6:
        next_speed=0.
        next_position = -1.2 if next_position < -1.2 else 0.6
    return array([next_position,next_speed])

def mountain_car_uniform_state():
    return array([numpy.random.uniform(low=-1.2,high=0.6),numpy.random.uniform(low=-0.07,high=0.07)])
mountain_car_mu_position, mountain_car_mu_speed = meshgrid(linspace(-1.2,0.6,7),linspace(-0.07,0.07,7))

mountain_car_sigma_position = 2*pow((0.6+1.2)/10.,2)
mountain_car_sigma_speed = 2*pow((0.07+0.07)/10.,2)

def mountain_car_single_psi(state):
    position,speed=state
    psi=[]
    for mu in zip_stack(mountain_car_mu_position, mountain_car_mu_speed).reshape(7*7,2):
        psi.append(exp( -pow(position-mu[0],2)/mountain_car_sigma_position 
                        -pow(speed-mu[1],2)/mountain_car_sigma_speed))
    psi.append(1.)
    return array(psi).reshape((7*7+1,1))

mountain_car_psi= non_scalar_vectorize(mountain_car_single_psi,(2,),(50,1))

def mountain_car_single_phi(sa):
    state=sa[:2]
    index_action = int(sa[-1])+1
    answer=zeros(((7*7+1)*3,1))
    answer[index_action*(7*7+1):index_action*(7*7+1)+7*7+1] = mountain_car_single_psi(state)
    return answer

mountain_car_phi= non_scalar_vectorize(mountain_car_single_phi,(3,),(150,1))

def mountain_car_reward(sas):
    position=sas[0]
    return 1 if position > 0.5 else 0

def mountain_car_episode_length(initial_position,initial_speed,policy):
    answer = 0
    reward = 0.
    state = array([initial_position,initial_speed])
    while answer < 300 and reward == 0. :
        action = policy(state)
        next_state = mountain_car_next_state(state,action)
        reward = mountain_car_reward(hstack([state, action, next_state]))
        state=next_state
        answer+=1
    return answer

def mountain_car_episode_vlength(policy):
    return vectorize(lambda p,s:mountain_car_episode_length(p,s,policy))


def mountain_car_training_data(freward=mountain_car_reward,traj_length=5,nb_traj=1000):
    traj = []
    random_policy = lambda s:choice(ACTION_SPACE)
    for i in range(0,nb_traj):
        state = mountain_car_uniform_state()
        reward=0
        t=0
        while t < traj_length and reward == 0:
            t+=1
            action = random_policy(state)
            next_state = mountain_car_next_state(state, action)
            reward = freward(hstack([state, action, next_state]))
            traj.append(hstack([state, action, next_state, reward]))
            state=next_state
    return array(traj)
def mountain_car_plot( f, draw_contour=True, contour_levels=50, draw_surface=False ):
    '''Display a surface plot of function f over the state space'''
    pos = linspace(-1.2,0.6,30)
    speed = linspace(-0.07,0.07,30)
    pos,speed = meshgrid(pos,speed)
    Z = f(pos,speed)
    #fig = figure()
    if draw_surface:
        ax=Axes3D(fig)
        ax.plot_surface(pos,speed,Z)
    if draw_contour:
        contourf(pos,speed,Z,levels=linspace(min(Z.reshape(-1)),max(Z.reshape(-1)),contour_levels+1))
        colorbar()
def mountain_car_plot_policy( policy ):
    two_args_pol = lambda p,s:squeeze(policy(zip_stack(p,s)))
    mountain_car_plot(two_args_pol,contour_levels=3)

def mountain_car_V(omega):
    policy = greedy_policy( omega, mountain_car_phi, ACTION_SPACE )
    def V(pos,speed):
        actions = policy(zip_stack(pos,speed))
        Phi=mountain_car_phi(zip_stack(pos,speed,actions))
        return squeeze(dot(omega.transpose(),Phi))
    return V

def mountain_car_interesting_state():
    position = numpy.random.uniform(low=-1.2,high=-0.9)
    speed = numpy.random.uniform(low=-0.07,high=0)
    return array([position,speed])

def mountain_car_IRL_traj():
    traj = []
    state = mountain_car_interesting_state()
    reward = 0
    while reward == 0:
        action = mountain_car_manual_policy(state)
        next_state = mountain_car_next_state(state, action)
        next_action = mountain_car_manual_policy(next_state)
        reward = mountain_car_reward(hstack([state, action, next_state]))
        traj.append(hstack([state, action, next_state, next_action, reward]))
        state=next_state
    return array(traj)

def mountain_car_IRL_data(nbsamples):
    data = mountain_car_IRL_traj()
    while len(data) < nbsamples:
        data = vstack([data,mountain_car_IRL_traj()])
    return data[:nbsamples]

def mountain_car_manual_policy(state):
    position,speed = state
    return -1. if speed <=0 else 1.

TRAJS = mountain_car_IRL_data(1000)
scatter(TRAJS[:,0],TRAJS[:,1],c=TRAJS[:,2])
axis([-1.2,0.6,-0.07,0.07])
phi=mountain_car_phi

# %%
def mountain_car_RE_traj():
    traj = []
    state = mountain_car_interesting_state()
    reward = 0
    t=0
    while reward == 0 and t<60:
        t+=1
        action = choice(ACTION_SPACE)
        next_state = mountain_car_next_state(state, action)
        reward = mountain_car_reward(hstack([state, action, next_state]))
        traj.append(hstack([state, action, next_state, reward]))
        state=next_state
    return array(traj)

data_r = vstack([mountain_car_RE_traj() for i in range(0,400)])
savetxt("mountain_car_RE_trajs.mat",data_r)

# %%
sqrt(-log2(1-0.0001)/(2*70))*(pow(0.99,(70+1))-1)/(0.99-1)#Epsilon
# Out:
# 0.051784252827375754

# %%
GAMMA = 0.99

def end_of_episode(data,i):
    try:
        if all(data[i,3:5] == data[i+1,:2]):
            return False
        else:
            return True
    except:
        return True

#Relative Entropy
class GradientDescent(object):
   def alpha( self, t ):
      raise NotImplementedError, "Cannot call abstract method"

   theta_0=None
   Threshold=None
   T = -1
   sign = None
        
   def run( self, f_grad, f_proj=None, b_norm=False, b_best=True ): #grad is a function of theta
      theta = self.theta_0.copy()
      best_theta = theta.copy()
      best_norm = float("inf")
      best_iter = 0
      t=0
      while True:#Do...while loop
         t+=1
         DeltaTheta = f_grad( theta )
         current_norm = norm( DeltaTheta )
         if b_norm and  current_norm > 0.:
             DeltaTheta /= norm( DeltaTheta )
         theta = theta + self.sign * self.alpha( t )*DeltaTheta
         if f_proj:
             theta = f_proj( theta )
         print "Norme du gradient : "+str(current_norm)+", pas : "+str(self.alpha(t))+", iteration : "+str(t)

         if current_norm < best_norm or not b_best:
             best_norm = current_norm
             best_theta = theta.copy()
             best_iter = t
         if current_norm < self.Threshold or (self.T != -1 and t >= self.T):
             break

      print "Gradient de norme : "+str(best_norm)+", a l'iteration : "+str(best_iter)
      return best_theta
                            
class RelativeEntropy(GradientDescent):
    sign=+1.
    Threshold=0.01 #Sensible default
    T=50 #Sensible default
    Epsilon = 0.05 #RelEnt parameter, sensible default

    def alpha(self, t):
        return 1./(t+1)#Sensible default
    
    def __init__(self, mu_E, mus):
        self.theta_0 = zeros(mu_E.shape)
        self.Mu_E = mu_E
        self.Mus = mus
    
    def gradient(self, theta):
        numerator = 0
        denominator = 0
        for mu in self.Mus:
            c = exp(dot(theta.transpose(),mu))
            numerator += c*mu
            denominator += c
        assert denominator != 0,"A sum of exp(...) is null, some black magic happened here."
        return self.Mu_E - numerator/denominator - sign(theta)*self.Epsilon
    
    def run(self):
        f_grad = lambda theta: self.gradient(theta)
        theta = super(RelativeEntropy,self).run( f_grad, b_norm=True, b_best=False)
        return theta

    
data_r_LSPI = genfromtxt("mountain_car_batch_data.mat") #See Exp4 : rho uniform, M=1000, L=5
data_r_RE = genfromtxt("mountain_car_RE_trajs.mat") #rho  interesting, M=400, L<=60
data_r_Other = mountain_car_training_data( nb_traj=50, traj_length=100) #rho uniform, M=50,L=100

#Computing the feature expectations
t=0.
Mu_E = zeros(((7*7+1)*3,1))
for i in range(0,len(TRAJS)):
    Mu_E += pow(GAMMA,t)*mountain_car_phi(TRAJS[i,:3])
    if end_of_episode(TRAJS,i):
        t=0.
    else:
        t+=1.
Mu_E /= float(len(TRAJS))

Mus_LSPI=[]
mu = zeros(((7*7+1)*3,1))
t=0.
for i in range(0,len(data_r_LSPI)):
    mu += pow(GAMMA,t)*mountain_car_phi(data_r_LSPI[i,:3])
    if end_of_episode(data_r_LSPI,i):
        mu /= t+1.
        Mus_LSPI.append(mu)
        t=0.
        mu = zeros(((7*7+1)*3,1))
    else:
        t += 1. 
Mus_LSPI.append(Mu_E)

Mus_RE=[]
mu = zeros(((7*7+1)*3,1))
t=0.
for i in range(0,len(data_r_RE)):
    mu += pow(GAMMA,t)*mountain_car_phi(data_r_RE[i,:3])
    if end_of_episode(data_r_RE,i):
        mu /= t+1.
        Mus_RE.append(mu)
        t=0.
        mu = zeros(((7*7+1)*3,1))
    else:
        t += 1. 
Mus_RE.append(Mu_E)

Mus_Other=[]
mu = zeros(((7*7+1)*3,1))
t=0.
for i in range(0,len(data_r_Other)):
    mu += pow(GAMMA,t)*mountain_car_phi(data_r_Other[i,:3])
    if end_of_episode(data_r_Other,i):
        mu /= t+1.
        Mus_Other.append(mu)
        t=0.
        mu = zeros(((7*7+1)*3,1))
    else:
        t += 1. 
Mus_Other.append(Mu_E)

RE_LSPI = RelativeEntropy(Mu_E, Mus_LSPI)
theta_RE_LSPI = RE_LSPI.run()
     
RE_RE = RelativeEntropy(Mu_E, Mus_RE)
theta_RE_RE = RE_RE.run()

RE_Other = RelativeEntropy(Mu_E, Mus_Other)
theta_RE_Other = RE_Other.run()
# Out:
# Norme du gradient : 0.635460315454, pas : 0.5, iteration : 1
# Norme du gradient : 0.605329014028, pas : 0.333333333333, iteration : 2
# Norme du gradient : 0.78895904988, pas : 0.25, iteration : 3
# Norme du gradient : 0.662083473137, pas : 0.2, iteration : 4
# Norme du gradient : 0.652424326479, pas : 0.166666666667, iteration : 5
# Norme du gradient : 0.652574293955, pas : 0.142857142857, iteration : 6
# Norme du gradient : 0.713481601402, pas : 0.125, iteration : 7
# Norme du gradient : 0.638978490957, pas : 0.111111111111, iteration : 8
# Norme du gradient : 0.637072538337, pas : 0.1, iteration : 9
# Norme du gradient : 0.68837576, pas : 0.0909090909091, iteration : 10
# Norme du gradient : 0.634706991733, pas : 0.0833333333333, iteration : 11
# Norme du gradient : 0.671016015102, pas : 0.0769230769231, iteration : 12
# Norme du gradient : 0.656127921927, pas : 0.0714285714286, iteration : 13
# Norme du gradient : 0.644122217225, pas : 0.0666666666667, iteration : 14
# Norme du gradient : 0.638010454174, pas : 0.0625, iteration : 15
# Norme du gradient : 0.667203618539, pas : 0.0588235294118, iteration : 16
# Norme du gradient : 0.65380522999, pas : 0.0555555555556, iteration : 17
# Norme du gradient : 0.626066061457, pas : 0.0526315789474, iteration : 18
# Norme du gradient : 0.654416441486, pas : 0.05, iteration : 19
# Norme du gradient : 0.654040622854, pas : 0.047619047619, iteration : 20
# Norme du gradient : 0.634342918875, pas : 0.0454545454545, iteration : 21
# Norme du gradient : 0.644688959412, pas : 0.0434782608696, iteration : 22
# Norme du gradient : 0.649112487977, pas : 0.0416666666667, iteration : 23
# Norme du gradient : 0.64677028104, pas : 0.04, iteration : 24
# Norme du gradient : 0.626539406837, pas : 0.0384615384615, iteration : 25
# Norme du gradient : 0.646501759954, pas : 0.037037037037, iteration : 26
# Norme du gradient : 0.6316408979, pas : 0.0357142857143, iteration : 27
# Norme du gradient : 0.648893464562, pas : 0.0344827586207, iteration : 28
# Norme du gradient : 0.637806024622, pas : 0.0333333333333, iteration : 29
# Norme du gradient : 0.624970135576, pas : 0.0322580645161, iteration : 30
# Norme du gradient : 0.65037308082, pas : 0.03125, iteration : 31
# Norme du gradient : 0.617988447294, pas : 0.030303030303, iteration : 32
# Norme du gradient : 0.657487110482, pas : 0.0294117647059, iteration : 33
# Norme du gradient : 0.631880113446, pas : 0.0285714285714, iteration : 34
# Norme du gradient : 0.63867621492, pas : 0.0277777777778, iteration : 35
# Norme du gradient : 0.630861596155, pas : 0.027027027027, iteration : 36
# Norme du gradient : 0.627375659067, pas : 0.0263157894737, iteration : 37
# Norme du gradient : 0.644217298997, pas : 0.025641025641, iteration : 38
# Norme du gradient : 0.622404038648, pas : 0.025, iteration : 39
# Norme du gradient : 0.633908721829, pas : 0.0243902439024, iteration : 40
# Norme du gradient : 0.63731831599, pas : 0.0238095238095, iteration : 41
# Norme du gradient : 0.633626741621, pas : 0.0232558139535, iteration : 42
# Norme du gradient : 0.620422784637, pas : 0.0227272727273, iteration : 43
# Norme du gradient : 0.65217579747, pas : 0.0222222222222, iteration : 44
# Norme du gradient : 0.618606516989, pas : 0.0217391304348, iteration : 45
# Norme du gradient : 0.631663214151, pas : 0.0212765957447, iteration : 46
# Norme du gradient : 0.634103191064, pas : 0.0208333333333, iteration : 47
# Norme du gradient : 0.635211285852, pas : 0.0204081632653, iteration : 48
# Norme du gradient : 0.610509628666, pas : 0.02, iteration : 49
# Norme du gradient : 0.634375421425, pas : 0.0196078431373, iteration : 50
# Gradient de norme : 0.634375421425, a l'iteration : 50
# Norme du gradient : 0.609264491458, pas : 0.5, iteration : 1
# Norme du gradient : 0.65453113131, pas : 0.333333333333, iteration : 2
# Norme du gradient : 0.714324714542, pas : 0.25, iteration : 3
# Norme du gradient : 0.701730237513, pas : 0.2, iteration : 4
# Norme du gradient : 0.683456827732, pas : 0.166666666667, iteration : 5
# Norme du gradient : 0.694845634856, pas : 0.142857142857, iteration : 6
# Norme du gradient : 0.710382998328, pas : 0.125, iteration : 7
# Norme du gradient : 0.684363417433, pas : 0.111111111111, iteration : 8
# Norme du gradient : 0.696311038124, pas : 0.1, iteration : 9
# Norme du gradient : 0.6941417904, pas : 0.0909090909091, iteration : 10
# Norme du gradient : 0.698725923696, pas : 0.0833333333333, iteration : 11
# Norme du gradient : 0.691379534463, pas : 0.0769230769231, iteration : 12
# Norme du gradient : 0.689182155064, pas : 0.0714285714286, iteration : 13
# Norme du gradient : 0.702624837854, pas : 0.0666666666667, iteration : 14
# Norme du gradient : 0.705224862562, pas : 0.0625, iteration : 15
# Norme du gradient : 0.679041047119, pas : 0.0588235294118, iteration : 16
# Norme du gradient : 0.707762096911, pas : 0.0555555555556, iteration : 17
# Norme du gradient : 0.699789982101, pas : 0.0526315789474, iteration : 18
# Norme du gradient : 0.702441446035, pas : 0.05, iteration : 19
# Norme du gradient : 0.698642801739, pas : 0.047619047619, iteration : 20
# Norme du gradient : 0.697713989206, pas : 0.0454545454545, iteration : 21
# Norme du gradient : 0.693442613368, pas : 0.0434782608696, iteration : 22
# Norme du gradient : 0.699989946264, pas : 0.0416666666667, iteration : 23
# Norme du gradient : 0.68683542948, pas : 0.04, iteration : 24
# Norme du gradient : 0.703233761812, pas : 0.0384615384615, iteration : 25
# Norme du gradient : 0.692308425838, pas : 0.037037037037, iteration : 26
# Norme du gradient : 0.698084166136, pas : 0.0357142857143, iteration : 27
# Norme du gradient : 0.705116211662, pas : 0.0344827586207, iteration : 28
# Norme du gradient : 0.706530016725, pas : 0.0333333333333, iteration : 29
# Norme du gradient : 0.689346841985, pas : 0.0322580645161, iteration : 30
# Norme du gradient : 0.695417607157, pas : 0.03125, iteration : 31
# Norme du gradient : 0.697111396164, pas : 0.030303030303, iteration : 32
# Norme du gradient : 0.690311753621, pas : 0.0294117647059, iteration : 33
# Norme du gradient : 0.716611884033, pas : 0.0285714285714, iteration : 34
# Norme du gradient : 0.690909854767, pas : 0.0277777777778, iteration : 35
# Norme du gradient : 0.695258998377, pas : 0.027027027027, iteration : 36
# Norme du gradient : 0.687576497479, pas : 0.0263157894737, iteration : 37
# Norme du gradient : 0.713564973432, pas : 0.025641025641, iteration : 38
# Norme du gradient : 0.709931440208, pas : 0.025, iteration : 39
# Norme du gradient : 0.69159385629, pas : 0.0243902439024, iteration : 40
# Norme du gradient : 0.712207649263, pas : 0.0238095238095, iteration : 41
# Norme du gradient : 0.67733942538, pas : 0.0232558139535, iteration : 42
# Norme du gradient : 0.691898789845, pas : 0.0227272727273, iteration : 43
# Norme du gradient : 0.701549451726, pas : 0.0222222222222, iteration : 44
# Norme du gradient : 0.704246595553, pas : 0.0217391304348, iteration : 45
# Norme du gradient : 0.689599589271, pas : 0.0212765957447, iteration : 46
# Norme du gradient : 0.703622297615, pas : 0.0208333333333, iteration : 47
# Norme du gradient : 0.697049895761, pas : 0.0204081632653, iteration : 48
# Norme du gradient : 0.710673478492, pas : 0.02, iteration : 49
# Norme du gradient : 0.699067876568, pas : 0.0196078431373, iteration : 50
# Gradient de norme : 0.699067876568, a l'iteration : 50
# Norme du gradient : 0.544593650756, pas : 0.5, iteration : 1
# Norme du gradient : 0.588526186811, pas : 0.333333333333, iteration : 2
# Norme du gradient : 0.723791154656, pas : 0.25, iteration : 3
# Norme du gradient : 0.615956741945, pas : 0.2, iteration : 4
# Norme du gradient : 0.670207342616, pas : 0.166666666667, iteration : 5
# Norme du gradient : 0.625261394566, pas : 0.142857142857, iteration : 6
# Norme du gradient : 0.65118988959, pas : 0.125, iteration : 7
# Norme du gradient : 0.628959871226, pas : 0.111111111111, iteration : 8
# Norme du gradient : 0.626727171525, pas : 0.1, iteration : 9
# Norme du gradient : 0.643061308399, pas : 0.0909090909091, iteration : 10
# Norme du gradient : 0.630384197956, pas : 0.0833333333333, iteration : 11
# Norme du gradient : 0.614961846322, pas : 0.0769230769231, iteration : 12
# Norme du gradient : 0.623941263454, pas : 0.0714285714286, iteration : 13
# Norme du gradient : 0.634962769393, pas : 0.0666666666667, iteration : 14
# Norme du gradient : 0.62412336601, pas : 0.0625, iteration : 15
# Norme du gradient : 0.630995825189, pas : 0.0588235294118, iteration : 16
# Norme du gradient : 0.617899701705, pas : 0.0555555555556, iteration : 17
# Norme du gradient : 0.631441111139, pas : 0.0526315789474, iteration : 18
# Norme du gradient : 0.613665214063, pas : 0.05, iteration : 19
# Norme du gradient : 0.625350422723, pas : 0.047619047619, iteration : 20
# Norme du gradient : 0.640000341665, pas : 0.0454545454545, iteration : 21
# Norme du gradient : 0.60491723794, pas : 0.0434782608696, iteration : 22
# Norme du gradient : 0.63093600076, pas : 0.0416666666667, iteration : 23
# Norme du gradient : 0.607429435148, pas : 0.04, iteration : 24
# Norme du gradient : 0.619047862182, pas : 0.0384615384615, iteration : 25
# Norme du gradient : 0.627767229766, pas : 0.037037037037, iteration : 26
# Norme du gradient : 0.62515434276, pas : 0.0357142857143, iteration : 27
# Norme du gradient : 0.607777903244, pas : 0.0344827586207, iteration : 28
# Norme du gradient : 0.613921349015, pas : 0.0333333333333, iteration : 29
# Norme du gradient : 0.630811270821, pas : 0.0322580645161, iteration : 30
# Norme du gradient : 0.589573621341, pas : 0.03125, iteration : 31
# Norme du gradient : 0.63844715425, pas : 0.030303030303, iteration : 32
# Norme du gradient : 0.612877230479, pas : 0.0294117647059, iteration : 33
# Norme du gradient : 0.614911640738, pas : 0.0285714285714, iteration : 34
# Norme du gradient : 0.61345670749, pas : 0.0277777777778, iteration : 35
# Norme du gradient : 0.615097788202, pas : 0.027027027027, iteration : 36
# Norme du gradient : 0.621271140234, pas : 0.0263157894737, iteration : 37
# Norme du gradient : 0.601780754707, pas : 0.025641025641, iteration : 38
# Norme du gradient : 0.62137995642, pas : 0.025, iteration : 39
# Norme du gradient : 0.615849131168, pas : 0.0243902439024, iteration : 40
# Norme du gradient : 0.613080408595, pas : 0.0238095238095, iteration : 41
# Norme du gradient : 0.610554512135, pas : 0.0232558139535, iteration : 42
# Norme du gradient : 0.615386566187, pas : 0.0227272727273, iteration : 43
# Norme du gradient : 0.614253235357, pas : 0.0222222222222, iteration : 44
# Norme du gradient : 0.603905730826, pas : 0.0217391304348, iteration : 45
# Norme du gradient : 0.618463844565, pas : 0.0212765957447, iteration : 46
# Norme du gradient : 0.604466588234, pas : 0.0208333333333, iteration : 47
# Norme du gradient : 0.624843194033, pas : 0.0204081632653, iteration : 48
# Norme du gradient : 0.601166032485, pas : 0.02, iteration : 49
# Norme du gradient : 0.617747457248, pas : 0.0196078431373, iteration : 50
# Gradient de norme : 0.617747457248, a l'iteration : 50

# %%
def RE_reward_LSPI(sas):
    sa = sas[:3]
    return squeeze(dot(theta_RE_LSPI.transpose(),mountain_car_phi(sa)))
vRE_reward = non_scalar_vectorize( RE_reward_LSPI, (5,),(1,1) )
data = genfromtxt("mountain_car_batch_data.mat")
data[:,5] = squeeze(vRE_reward(data[:,:5]))
policy_RE_LSPI,omega_RE = lspi( data, s_dim=2,a_dim=1, A=ACTION_SPACE, phi=mountain_car_phi, phi_dim=150, iterations_max=20 )

def RE_reward_RE(sas):
    sa = sas[:3]
    return squeeze(dot(theta_RE_RE.transpose(),mountain_car_phi(sa)))
vRE_reward = non_scalar_vectorize( RE_reward_RE, (5,),(1,1) )
data = genfromtxt("mountain_car_batch_data.mat")
data[:,5] = squeeze(vRE_reward(data[:,:5]))
policy_RE_RE,omega_RE = lspi( data, s_dim=2,a_dim=1, A=ACTION_SPACE, phi=mountain_car_phi, phi_dim=150, iterations_max=20 )

def RE_reward_Other(sas):
    sa = sas[:3]
    return squeeze(dot(theta_RE_Other.transpose(),mountain_car_phi(sa)))
vRE_reward = non_scalar_vectorize( RE_reward_Other, (5,),(1,1) )
data = genfromtxt("mountain_car_batch_data.mat")
data[:,5] = squeeze(vRE_reward(data[:,:5]))
policy_RE_Other,omega_RE = lspi( data, s_dim=2,a_dim=1, A=ACTION_SPACE, phi=mountain_car_phi, phi_dim=150, iterations_max=20 )

mountain_car_plot_policy(policy_RE_LSPI)
figure()
mountain_car_plot_policy(policy_RE_RE)
figure()
mountain_car_plot_policy(policy_RE_Other)
# Out:
# LSPI, iter :1, diff : 11.9454677893
# LSPI, iter :2, diff : 40.2599324863
# LSPI, iter :3, diff : 0.0
# LSPI, iter :1, diff : 6.36784739925
# LSPI, iter :2, diff : 41.7018123548
# LSPI, iter :3, diff : 0.0
# LSPI, iter :1, diff : 2.17552929909
# LSPI, iter :2, diff : 34.0257299734
# LSPI, iter :3, diff : 0.0

# %%
plottable_episode_length = mountain_car_episode_vlength(policy_RE)
X = linspace(-1.2,0.6,20)
Y = linspace(-0.07,0.07,20)
X,Y = meshgrid(X,Y)
Z2 = plottable_episode_length(X,Y)
figure()
mountain_car_plot_policy(policy_RE)
figure()
contourf(X,Y,Z2,50)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x3ff3758>

# %%
def mountain_car_testing_state():
    position = numpy.random.uniform(low=-1.2,high=0.5)
    speed = numpy.random.uniform(low=-0.07,high=0.07)
    return array([position,speed])

def mountain_car_mean_performance(policy):
    return mean([mountain_car_episode_length(state[0],state[1],policy) for state in [mountain_car_testing_state() for i in range(0,100)]])

mountain_car_plot_policy(policy_RE)
print mountain_car_mean_performance(policy_RE)
# Out:
# 125.25
